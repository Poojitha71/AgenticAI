# %%
class Error(Exception):
    pass

class dobException(Error):
    pass

# %%
year = int(input("enter ypur year of dob: "))
age = 2026-year
try:
    if age<=30 and age>=20:
        print("age is valid to apply for the exams")
        
    else:
       raise dobException
except dobException:
    print("sorry, your age should be greater than 20 or less than 30")
# Out:
# age is valid to apply for the exams
